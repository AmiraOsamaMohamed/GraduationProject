# %% [markdown]
# <a href="https://colab.research.google.com/github/AmiraOsamaMohamed/GraduationProject/blob/main/Preprocessing_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Preprocessing

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import nltk
import re
import spacy
from nltk import word_tokenize , sent_tokenize
from nltk.corpus import stopwords

# %%
#read json file and convert it to DataFrame
import json
def read_data(path):
 data = []

 with open(path) as trainFile:
    for line in trainFile:
        data.append(json.loads(line))
 all_data=pd.DataFrame(data)
 all_data.head()
 #split col(answers) to text and start_char and combine them as base columns in big DataFrame
 line=[]
 list_text=[]
 list_start_char=[]
 list_pq_id=[]

 for i in range(0,len(data)):
   line.extend(data[i]['answers'])


 for i in range(0,len(data)):
   list_text.append(line[i]['text'])



 for i in range(0,len(data)):
   list_start_char.append(line[i]['start_char'])



 for i in range(0,len(data)):
   list_pq_id.append(data[i]['pq_id'])



 answer_df=pd.DataFrame(list_pq_id,columns=['pq_id'])
 answer_df['text']=list_text
 answer_df['start_char']=list_start_char
 answer_df.head()

#merge between 2 DataFrame
 merged_data = pd.merge(all_data, answer_df, on="pq_id")
 merged_data = merged_data.drop(columns=["answers"])
 merged_data = merged_data.rename(columns={"text":"answer"})
 merged_data.head()
 return merged_data

# %%
#convert merged data to csv file
train=read_data('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_train.jsonl')
validation=read_data('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_dev.jsonl')
test=read_data('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_test_gold.jsonl')
train.to_csv('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_train.csv', index=False)
validation.to_csv('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_dev.csv', index=False)
test.to_csv('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_test_gold.csv', index=False)

# %%
#clean text
def clean(text):
    text = re.sub(r"http\S+", " ", text)  # remove urls
    text = re.sub(r"@[\w]*", " ", text)  # remove handles
    text = re.sub(r"[\.\,\#_\|\:\?\?\/\=]", " ", text) # remove special characters
    text = re.sub(r"\t", " ", text)  # remove tabs
    text = re.sub(r"\n", " ", text)  # remove line jump
    text = re.sub(r"\s+", " ", text)  # remove extra white space
    text = re.sub(r'[^\w\s]', '', text) # Removing punctuations in string using regex
    text = text.strip()
    return text

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
# Function to tokenize sentences
def tokenize_words(text):
    return word_tokenize(text)

# Function to remove stopwords from tokenized text
stop_words = set(stopwords.words('arabic'))
def remove_stopwords(tokenized_text):
    return [word for word in tokenized_text if word not in stop_words]


# Function to return to the base of word(stemmer) from tokenized text
stemmer = SnowballStemmer('arabic')
def stem_words(tokenized_text):
    return [stemmer.stem(word) for word in tokenized_text]


def processed_text(text):
  cleaned_text=clean(text)
  tokenized_text=tokenize_words(cleaned_text)
  underProcessing_text=remove_stopwords(tokenized_text)
  processed_text=stem_words(underProcessing_text)
  return processed_text


# Apply the functions(processing) to the DataFrame
train['processed passage'] = train['passage'].apply(processed_text)


train['processed question'] = train['question'].apply(processed_text)


train['processed answer'] = train['answer'].apply(processed_text)



# Print the DataFrame
train.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#           pq_id                                            passage surah  \
# 0     2:1-5_372  الم. ذلك الكتاب لا ريب فيه هدى للمتقين. الذين ...     2
# 1   2:23-24_372  وإن كنتم في ريب مما نزلنا على عبدنا فأتوا بسور...     2
# 2   2:40-48_372  يا بني إسرائيل اذكروا نعمتي التي أنعمت عليكم و...     2
# 3   2:91-93_372  وإذا قيل لهم آمنوا بما أنزل الله قالوا نؤمن بم...     2
# 4  2:97-101_372  قل من كان عدوا لجبريل فإنه نزله على قلبك بإذن ...     2
#
#    verses                                           question  \
# 0     1-5  ما الدلائل على أن القرآن ليس من تأليف سيدنا مح...
# 1   23-24  ما الدلائل على أن القرآن ليس من تأليف سيدنا مح...
# 2   40-48  ما الدلائل على أن القرآن ليس من تأليف سيدنا مح...
# 3   91-93  ما الدلائل على أن القرآن ليس من تأليف سيدنا مح...
# 4  97-101  ما الدلائل على أن القرآن ليس من تأليف سيدنا مح...
#
#                                               answer  start_char  \
# 0        الذين يؤمنون بما أنزل إليك وما أنزل من قبلك          97
# 1  إن كنتم في ريب مما نزلنا على عبدنا فأتوا بسورة...           1
# 2                     آمنوا بما أنزلت مصدقا لما معكم          85
# 3                    إذا قيل لهم آمنوا بما أنزل الله           1
# 4                             هو الحق مصدقا لما معهم          78
#
#                                    processed passage  \
# 0  [الم, كتاب, ريب, هدى, متق, يومن, غيب, يقيم, صل...
# 1  [كنتم, ريب, نزل, عبد, اتو, سور, مثل, وادع, شهد...
# 2  [بن, اسراييل, اذكر, نعم, انعم, عل, اوف, عهد, ا...
# 3  [قيل, امنو, انزل, الله, قالو, نوم, انزل, عل, ي...
# 4  [قل, عدو, جبريل, فان, نزل, قلب, باذ, الله, مصد...
#
#                processed question                      processed answer
# 0  [دلايل, قرء, تاليف, سيد, محمد]               [يومن, انزل, انزل, قبل]
# 1  [دلايل, قرء, تاليف, سيد, محمد]  [كنتم, ريب, نزل, عبد, اتو, سور, مثل]
# 2  [دلايل, قرء, تاليف, سيد, محمد]              [امنو, انزل, مصدق, معكم]
# 3  [دلايل, قرء, تاليف, سيد, محمد]               [قيل, امنو, انزل, الله]
# 4  [دلايل, قرء, تاليف, سيد, محمد]                    [الحق, مصدق, معهم]

# %%
validation['processed passage'] = validation['passage'].apply(processed_text)


validation['processed question'] = validation['question'].apply(processed_text)


validation['processed answer'] = validation['answer'].apply(processed_text)

validation.head()
# Out:
#           pq_id                                            passage surah  \
# 0  13:18-24_360  للذين استجابوا لربهم الحسنى والذين لم يستجيبوا...    13
# 1    40:7-9_360  الذين يحملون العرش ومن حوله يسبحون بحمد ربهم و...    40
# 2  52:17-28_360  إن المتقين في جنات ونعيم. فاكهين بما آتاهم ربه...    52
# 3  73:15-19_386  إنا أرسلنا إليكم رسولا شاهدا عليكم كما أرسلنا ...    73
# 4  28:76-81_114  إن قارون كان من قوم موسى فبغى عليهم وآتيناه من...    28
#
#   verses                                           question  \
# 0  18-24  هل سيجمع الله بين المؤمنين وأبنائهم وأهلهم في ...
# 1    7-9  هل سيجمع الله بين المؤمنين وأبنائهم وأهلهم في ...
# 2  17-28  هل سيجمع الله بين المؤمنين وأبنائهم وأهلهم في ...
# 3  15-19  هل هناك علاقة بين الخوف أو الاضطرابات النفسية ...
# 4  76-81                         من الذي خسف الله به الأرض؟
#
#                                               answer  start_char  \
# 0  جنات عدن يدخلونها ومن صلح من آبائهم وأزواجهم و...         451
# 1  ربنا وأدخلهم جنات عدن التي وعدتهم ومن صلح من آ...         156
# 2  الذين آمنوا واتبعتهم ذريتهم بإيمان ألحقنا بهم ...         151
# 3          كيف تتقون إن كفرتم يوما يجعل الولدان شيبا         102
# 4                                              قارون         479
#
#                                    processed passage  \
# 0  [ذين, استجاب, لرب, حسنى, يستجيب, ارض, جميع, مث...
# 1  [يحمل, عرش, حول, يسبح, حمد, ربهم, يومن, يستغفر...
# 2  [متق, جنا, نعيم, فاكه, اتا, ربهم, ووق, ربهم, ع...
# 3  [ارسل, رسول, شاهد, عل, ارسل, رعو, رسول, عصى, ر...
# 4  [قارو, قوم, موسى, بغى, عل, اتين, كنوز, مفاتح, ...
#
#                       processed question  \
# 0  [سيجمع, الله, مومن, ابناء, اهل, الجن]
# 1  [سيجمع, الله, مومن, ابناء, اهل, الجن]
# 2  [سيجمع, الله, مومن, ابناء, اهل, الجن]
# 3          [علاق, خوف, اضطراب, نفس, شيب]
# 4                       [خسف, الله, ارض]
#
#                                     processed answer
# 0            [جنا, عدن, يدخل, صلح, اباء, ازواج, وذر]
# 1  [ربن, ادخل, جنا, عدن, وعد, صلح, اباء, ازواج, وذر]
# 2                   [امنو, واتبع, ذر, ايم, الحق, ذر]
# 3                  [تتقو, فرتم, يوم, يجعل, ولد, شيب]
# 4                                             [قارو]

# %%
test['processed passage'] = test['passage'].apply(processed_text)


test['processed question'] = test['question'].apply(processed_text)


test['processed answer'] = test['answer'].apply(processed_text)

test.head()
# Out:
#          pq_id                                            passage surah  \
# 0    2:1-5_570  الم. ذلك الكتاب لا ريب فيه هدى للمتقين. الذين ...     2
# 1    2:1-5_610  الم. ذلك الكتاب لا ريب فيه هدى للمتقين. الذين ...     2
# 2  2:21-22_505  يا أيها الناس اعبدوا ربكم الذي خلقكم والذين من...     2
# 3  2:34-39_568  وإذ قلنا للملائكة اسجدوا لآدم فسجدوا إلا إبليس...     2
# 4  2:60-62_611  وإذ استسقى موسى لقومه فقلنا اضرب بعصاك الحجر ف...     2
#
#   verses                                           question  \
# 0    1-5                       من هو المؤمن  بتعريف القرآن؟
# 1    1-5  ما الرد على الزعم باحتواء القرآن مفاهيم عقلية ...
# 2  21-22  ما الدلائل على أن القرآن أُنزل لجميع الناس أو ...
# 3  34-39                       لماذا يعادي الشيطان الإنسان؟
# 4  60-62  هل هناك دليل أو أدلة على وحدة الأديان التي أنز...
#
#                                               answer  start_char  \
# 0  الذين يؤمنون بالغيب ويقيمون الصلاة ومما رزقناه...          40
# 1  الذين يؤمنون بما أنزل إليك وما أنزل من قبلك وب...          97
# 2                              ذلك الكتاب لا ريب فيه           5
# 3  يا أيها الناس اعبدوا ربكم الذي خلقكم والذين من...           0
# 4  إذ قلنا للملائكة اسجدوا لآدم فسجدوا إلا إبليس ...           1
#
#                                    processed passage  \
# 0  [الم, كتاب, ريب, هدى, متق, يومن, غيب, يقيم, صل...
# 1  [الم, كتاب, ريب, هدى, متق, يومن, غيب, يقيم, صل...
# 2  [ناس, اعبد, ربكم, خلق, قبل, لعل, تتقو, ارض, را...
# 3  [قلن, ملايك, اسجد, لادم, سجد, ابليس, ابى, واست...
# 4  [استسقى, موسى, لقوم, فقل, اضرب, بعص, حجر, فانف...
#
#                                   processed question  \
# 0                                  [موم, تعريف, قرء]
# 1  [الرد, زعم, احتواء, قرء, مفاهيم, عقل, علم, مغلوط]
# 2           [دلايل, قرء, انزل, جميع, ناس, امم, شعوب]
# 3                             [لماذ, يعاد, شيط, انس]
# 4                 [دليل, ادل, وحد, الاد, انزل, الله]
#
#                                     processed answer
# 0            [يومن, غيب, يقيم, صلا, ومم, رزقن, ينفق]
# 1                 [يومن, انزل, انزل, قبل, اخر, يوقن]
# 2                                        [كتاب, ريب]
# 3                        [ناس, اعبد, ربكم, خلق, قبل]
# 4  [قلن, ملايك, اسجد, لادم, سجد, ابليس, ابى, واست...

# %%
train.to_csv('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_train.csv', index=False)
validation.to_csv('/content/drive/MyDrive/data/QQA23_TaskB_qrcdv1.2_dev.csv', index=False)
test.to_csv('/content/drive/MyDrive/data/QQA23_TaskB_qrcd_v1.2_test_gold.csv', index=False)
