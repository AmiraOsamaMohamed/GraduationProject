# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
scores=pd.read_json("all_scores.json").T

# %%
scores.head(8)
# Out:
#                                                      pRR  exact_match  \
# CAMeL-Lab/bert-base-arabic-camelbert-mix        0.129068     0.003663
# CAMeL-Lab/bert-base-arabic-camelbert-ca         0.116466     0.003663
# bert-base-cased                                 0.107868     0.001221
# bert-base-uncased                               0.100323     0.002442
# aubmindlab/araelectra-base-generator            0.133602     0.003663
# aubmindlab/araelectra-base-discriminator        0.127168     0.002442
# aubmindlab/bert-large-arabertv2                 0.131282     0.002442
# IProject-10/bert-base-uncased-finetuned-squad2  0.056892     0.001221
#
#                                                       f1
# CAMeL-Lab/bert-base-arabic-camelbert-mix        0.103499
# CAMeL-Lab/bert-base-arabic-camelbert-ca         0.092620
# bert-base-cased                                 0.078589
# bert-base-uncased                               0.070616
# aubmindlab/araelectra-base-generator            0.103318
# aubmindlab/araelectra-base-discriminator        0.094930
# aubmindlab/bert-large-arabertv2                 0.096985
# IProject-10/bert-base-uncased-finetuned-squad2  0.096985

# %%
scores=scores.reset_index()
scores=scores.rename(columns={'index': 'model'})
scores.head(8)
# Out:
#                                             model       pRR  exact_match  \
# 0        CAMeL-Lab/bert-base-arabic-camelbert-mix  0.129068     0.003663
# 1         CAMeL-Lab/bert-base-arabic-camelbert-ca  0.116466     0.003663
# 2                                 bert-base-cased  0.107868     0.001221
# 3                               bert-base-uncased  0.100323     0.002442
# 4            aubmindlab/araelectra-base-generator  0.133602     0.003663
# 5        aubmindlab/araelectra-base-discriminator  0.127168     0.002442
# 6                 aubmindlab/bert-large-arabertv2  0.131282     0.002442
# 7  IProject-10/bert-base-uncased-finetuned-squad2  0.056892     0.001221
#
#          f1
# 0  0.103499
# 1  0.092620
# 2  0.078589
# 3  0.070616
# 4  0.103318
# 5  0.094930
# 6  0.096985
# 7  0.096985

# %%
scores['model'].values
# Out:
# array(['CAMeL-Lab/bert-base-arabic-camelbert-mix',
#        'CAMeL-Lab/bert-base-arabic-camelbert-ca', 'bert-base-cased',
#        'bert-base-uncased', 'aubmindlab/araelectra-base-generator',
#        'aubmindlab/araelectra-base-discriminator',
#        'aubmindlab/bert-large-arabertv2',
#        'IProject-10/bert-base-uncased-finetuned-squad2'], dtype=object)

# %%
scores.columns
# Out:
# Index(['model', 'pRR', 'exact_match', 'f1'], dtype='object')

# %%
scores.plot.barh(x='model', y=[ 'pRR', 'exact_match', 'f1'], rot=0)

# Set the plot title and axis labels
plt.title('Scores by model')
plt.xlabel('Scores')
plt.ylabel('Model')
plt.legend(loc="upper left", frameon= True)

# Display the plot
plt.show()
